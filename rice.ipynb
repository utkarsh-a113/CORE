# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarsh-a113/CORE/blob/main/rice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading Imports

# %% [markdown]
# Importing libraries

# %%
# !pip install keras matplotlib numpy pandas tensorflow
print('\n\nAll requirements installed')
# Out:
# ...
#
#
# All requirements installed

# %% [markdown]
# Loading the imports

# %%
import keras
import numpy as np
import pandas as pd
import plotly.express as px
import tensorflow as tf
pd.options.display.max_rows=10
pd.options.display.float_format="{:.1f}".format

print("Ran them all.")
# Out:
# Ran them all.

# %% [markdown]
# Loading the dataset from kaggle

# %%
# !pip install kaggle

# %%
# from google.colab import files
# files.upload()
# Out:
#      <input type="file" id="files-d1169d26-3971-4dcc-8cb0-4921bad69ee7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1169d26-3971-4dcc-8cb0-4921bad69ee7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #importing from drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
# source=r"C:\Users\Lenovo\Downloads\kaggle.json"

destination = os.path.expanduser("~/.kaggle/kaggle.json")
# create kaggle folder if not existing

os.makedirs(os.path.dirname(destination), exist_ok=True)

shutil.move("kaggle.json", destination)

print("kaggle.json moved successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     846     try:
# --> 847         os.rename(src, real_dst)
#     848     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kaggle.json' -> '/root/.kaggle/kaggle.json'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2706922999.py in <cell line: 0>()
#       8 os.makedirs(os.path.dirname(destination), exist_ok=True)
#       9
# ---> 10 shutil.move("kaggle.json", destination)
#      11
#      12 print("kaggle.json moved successfully")
#
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     865             rmtree(src)
#     866         else:
# --> 867             copy_function(src, real_dst)
# ...
